# %%
import pandas as pd
import matplotlib.pyplot as plt
from pypalettes import load_cmap
from pyfonts import load_font
from highlight_text import fig_text, ax_text
from drawarrow import fig_arrow, ax_arrow

path = 'https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/temperature-variation.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Year  Change  Lowess(5)
# 0  1881   -0.09      -0.13
# 1  1882   -0.11      -0.17
# 2  1883   -0.18      -0.21
# 3  1884   -0.29      -0.24
# 4  1885   -0.34      -0.27

# %%
fig, ax = plt.subplots(figsize=(15,8), dpi=300)

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   ax.scatter(x=year, y=change, color='blue')
   ax.plot([year,year], [0,change], color='blue')

plt.savefig('temperature-1.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   ax.scatter(x=year, y=change, color='blue')
   ax.plot([year,year], [0,change], color='blue')

plt.savefig('temperature-2.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

plt.savefig('temperature-3.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', size=15, ha='left')

plt.savefig('temperature-4.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', color=cmap(value), size=9, va='center')

plt.savefig('temperature-5.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', color=cmap(value), size=9, va='center')

s = 'Global Land-Ocean Temperature Index'
ax_text(x=1881, y=1.1, s=s, size=35, ha='left')

plt.savefig('temperature-6.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', color=cmap(value), size=9, va='center')

s = 'Global Land-Ocean Temperature Index'
ax_text(x=1881, y=1.1, s=s, size=35, ha='left')

s = 'Change in global surface temperature compared to the long-term average from 1951 to 1980'
ax_text(x=1881, y=0.94, s=s, size=16, ha='left')

plt.savefig('temperature-7.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', color=cmap(value), size=9, va='center')

s = 'Global Land-Ocean Temperature Index'
ax_text(x=1881, y=1.1, s=s, size=35, ha='left')

s = 'Change in global surface temperature compared to the long-term average from 1951 to 1980'
ax_text(x=1881, y=0.94, s=s, size=16, ha='left')

s = '<Graph>: barbierjoseph.com\n<Data Source>: NASA'
ax_text(x=1881, y=-0.7, s=s, size=8, ha='left')

plt.savefig('temperature-8.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', color=cmap(value), size=9, va='center')

s = 'Global Land-Ocean Temperature Index'
ax_text(x=1881, y=1.1, s=s, size=35, ha='left')

s = 'Change in global surface temperature compared to the long-term average from 1951 to 1980'
ax_text(x=1881, y=0.94, s=s, size=16, ha='left')

s = '<Graph>: barbierjoseph.com\n<Data Source>: NASA'
ax_text(x=1881, y=-0.7, s=s, size=8, ha='left')

s = 'Heat waves in Europe\nin the 1940s'
ax_text(x=1915, y=0.52, s=s, size=10, ha='left')

s = 'Beginning of only positive\nvalues in global change'
ax_text(x=2018, y=-0.2, s=s, size=10, ha='right')

plt.savefig('temperature-9.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)
arrow_props = dict(color='black', tail_width=0.05, linewidth=0.5, head_width=3, head_length=5)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)

   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', color=cmap(value), size=9, va='center')

s = 'Global Land-Ocean Temperature Index'
ax_text(x=1881, y=1.1, s=s, size=35, ha='left')

s = 'Change in global surface temperature compared to the long-term average from 1951 to 1980'
ax_text(x=1881, y=0.94, s=s, size=16, ha='left')

s = '<Graph>: barbierjoseph.com\n<Data Source>: NASA'
ax_text(x=1881, y=-0.7, s=s, size=8, ha='left')

s = 'Heat waves in Europe\nin the 1940s'
ax_text(x=1915, y=0.52, s=s, size=10, ha='left')
ax_arrow(
   tail_position=(1927, 0.43), head_position=(1938, 0.2), **arrow_props
)

s = 'Beginning of only positive\nvalues in global change'
ax_text(x=2018, y=-0.2, s=s, size=10, ha='right')
ax_arrow(
   tail_position=(1996, -0.22), head_position=(1980, -0.05), invert=True, **arrow_props
)

plt.savefig('temperature-10.png', bbox_inches='tight', dpi=300)
plt.close()

############################################

cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)
arrow_props = dict(color='black', tail_width=0.05, linewidth=0.5, head_width=3, head_length=5)
font = load_font('https://github.com/coreyhu/Urbanist/blob/main/fonts/ttf/Urbanist-Light.ttf?raw=true')
bold_font = load_font('https://github.com/coreyhu/Urbanist/blob/main/fonts/ttf/Urbanist-Medium.ttf?raw=true')

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)
   
   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', font=font, size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', font=font, size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', font=font, color=cmap(value), size=9, va='center')

s = 'Global Land-Ocean Temperature Index'
ax_text(x=1881, y=1.1, s=s, font=font, size=35, ha='left')

s = 'Change in global surface temperature compared to the long-term average from 1951 to 1980'
ax_text(x=1881, y=0.94, s=s, font=font, size=16, ha='left', color='grey', alpha=0.7)

s = '<Graph>: barbierjoseph.com\n<Data Source>: NASA'
ax_text(x=1881, y=-0.7, s=s, font=font, size=8, ha='left', highlight_textprops=[{'font': bold_font}]*2)

s = 'Heat waves in Europe\nin the 1940s'
ax_text(x=1915, y=0.52, s=s, font=font, size=10, ha='left')
ax_arrow(
   tail_position=(1927, 0.43), head_position=(1938, 0.2), **arrow_props
)

s = 'Beginning of only positive\nvalues in global change'
ax_text(x=2018, y=-0.2, s=s, font=font, size=10, ha='right')
ax_arrow(
   tail_position=(1996, -0.22), head_position=(1980, -0.05), invert=True, **arrow_props
)

plt.savefig('temperature-11.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
cmap = load_cmap('Coconut', cmap_type='continuous', reverse=True)
font = load_font('https://github.com/coreyhu/Urbanist/blob/main/fonts/ttf/Urbanist-Light.ttf?raw=true')
bold_font = load_font('https://github.com/coreyhu/Urbanist/blob/main/fonts/ttf/Urbanist-Medium.ttf?raw=true')
arrow_props = dict(color='black', tail_width=0.05, linewidth=0.5, head_width=3, head_length=5)

fig, ax = plt.subplots(figsize=(15,8), dpi=300)
ax.set_axis_off()

for i, row in df.iterrows():
   year = row['Year']
   change = row['Change']
   color = cmap(change)
   ax.scatter(x=year, y=change, color=color)
   ax.plot([year,year], [0,change], color=color, alpha=0.8)
   
   if year % 20 == 0:
      ax.text(x=year, y=-0.6, s=f'{year:.0f}', font=font, size=15, ha='left')
ax.text(x=1881, y=-0.6, s=f'{1880}', font=font, size=15, ha='left')

h_lines = [-0.4, 0, 0.4, 0.8]
ax.hlines(y=h_lines, xmin=1881, xmax=2023, colors=[cmap(val) for val in h_lines], linewidth=1.2, zorder=-1, alpha=0.5)
for value in h_lines:
   ax.text(x=1877, y=value, s=f'{value}', font=font, color=cmap(value), size=9, va='center')

s = 'Global Land-Ocean Temperature Index'
ax_text(x=1881, y=1.1, s=s, font=font, size=35, ha='left')

s = 'Change in global surface temperature compared to the long-term average from 1951 to 1980'
ax_text(x=1881, y=0.94, s=s, font=font, size=16, ha='left', color='grey', alpha=0.7)

s = '<Graph>: barbierjoseph.com\n<Data Source>: NASA'
ax_text(x=1881, y=-0.7, s=s, font=font, size=8, ha='left', highlight_textprops=[{'font': bold_font}]*2)

s = 'Heat waves in Europe\nin the 1940s'
ax_text(x=1915, y=0.52, s=s, font=font, size=10, ha='left')
ax_arrow(
   tail_position=(1927, 0.43), head_position=(1938, 0.2), **arrow_props
)

s = 'Beginning of only positive\nvalues in global change'
ax_text(x=2018, y=-0.2, s=s, font=font, size=10, ha='right')
ax_arrow(
   tail_position=(1996, -0.22), head_position=(1980, -0.05), invert=True, **arrow_props
)

plt.show()
